# %%
import numpy.random

import scipy
import scipy.optimize
import scipy.constants
import math
import numpy 
import uncertainties
import uncertainties.unumpy 

import matplotlib.axes
import matplotlib.pyplot
import scipy.misc
import scipy.special
import scipy.stats
from random import *
from scipy.special import xlogy
import sys
from scipy.stats import norm

from scipy.optimize import curve_fit


from math import *
fn = "Bi209_p3n.txt"
Bi_data = numpy.loadtxt(fn)#, skiprows=4)
fn = "In115_pn.txt"
In_data_n = numpy.loadtxt(fn)#, skiprows=4)
fn = "In115_p2n.txt"
In_data_2n = numpy.loadtxt(fn)#, skiprows=4)
fn = "In115_p3n.txt"
In_data_3n = numpy.loadtxt(fn)#, skiprows=4)

# %%
matplotlib.rcParams['figure.figsize'] = 4.5, 3.5
matplotlib.pyplot.figure(dpi=200)
linestyles = ['-', '--', '-.', ':']

matplotlib.pyplot.semilogx(In_data_n[:,0],In_data_n[:,1], linestyle=linestyles[0])#, color='black')
matplotlib.pyplot.semilogx(In_data_2n[:,0],In_data_2n[:,1], linestyle=linestyles[1])#, color='black')
matplotlib.pyplot.semilogx(In_data_3n[:,0],In_data_3n[:,1], linestyle=linestyles[2])#, color='black')
matplotlib.pyplot.semilogx(Bi_data[:,0],Bi_data[:,1], linestyle=linestyles[3])#, color='black')


matplotlib.pyplot.xlabel('Proton Energy (MeV)')
matplotlib.pyplot.ylabel("Cross-section (mb)")
matplotlib.pyplot.grid(b=None, which='major', axis='both', color='grey', linestyle='-', linewidth=.5)
matplotlib.pyplot.legend(['In-115 (p,n)', 'In-115 (p,2n)','In-115 (p,3n)','Bi-209 (p,3n)'],loc='center left', fontsize=8)
#matplotlib.pyplot.ylim([0.5*10**4, 0.5*10**10])
matplotlib.pyplot.tight_layout()
matplotlib.pyplot.show()
